# %% [markdown]
# # 🇺🇦 Україна
#
# Це приклад Markdown + HTML у Jupyter Notebook.

# %% [markdown]
# ## Основна інформація
# - **Площа:** _603,628 км²_
# - **Населення:** **~36 млн**
# - **Устрій:** Унітарна парламентсько-президентська республіка

# %% [markdown]
# ## Видатні персоналії
# 1. **Тарас Шевченко**
# 2. _Леся Українка_
# 3. **Богдан Хмельницький**

# %% [markdown]
# ## Пам’ятки культури
# - Києво-Печерська Лавра
# - Софія Київська

# %% [markdown]
# <h3>🇺🇦 Прапор України (SVG):</h3>
# <svg width="180" height="120">
#   <rect width="180" height="60" fill="#0057b7"/>
#   <rect y="60" width="180" height="60" fill="#ffd700"/>
# </svg>

# %% [markdown]
# ## Зображення герба
#
# ![Герб України](https://upload.wikimedia.org/wikipedia/commons/thumb/5/57/Coat_of_Arms_of_Ukraine.svg/1024px-Coat_of_Arms_of_Ukraine.svg.png)

# %% [markdown]
# ## Гіперпосилання
#
# [Офіційний сайт Президента України](https://www.president.gov.ua)
